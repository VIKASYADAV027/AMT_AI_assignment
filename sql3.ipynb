# %% [markdown]
# <a href="https://colab.research.google.com/github/VIKASYADAV027/AMT_AI_assignment/blob/main/sql3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# %%
conn = sqlite3.connect("movies.db")
cur = conn.cursor()

# %%
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()
# Out:
# ('movies',)

# %%
cur.execute("""
      CREATE TABLE movies(
      id INT AUTOINREMENT,
      name VARCHAR(255),
      year YEAR NOT NULL
      )
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_2346/474138323.py in <cell line: 0>()
# ----> 1 cur.execute("""
#       2       CREATE TABLE movies(
#       3       id INT AUTOINREMENT,
#       4       name VARCHAR(255),
#       5       year YEAR NOT NULL
#
# OperationalError: table movies already exists

# %%
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()

# %%
cur.execute("INSERT INTO movies (name, year) VALUES ('The Matrix', 1999)")
cur.execute("INSERT INTO movies (name, year) VALUES ('The Matrix Reloaded', 2003)")
cur.execute("INSERT INTO movies (name, year) VALUES ('The Matrix Revolutions', 2003)")

# %%
cur.execute("SELECT * FROM movies")
cur.fetchall()
# Out:
# [(None, 'The Matrix', 1999),
#  (None, 'The Matrix Reloaded', 2003),
#  (None, 'The Matrix Revolutions', 2003),
#  (None, 'The Matrix', 1999),
#  (None, 'The Matrix Reloaded', 2003),
#  (None, 'The Matrix Revolutions', 2003)]

# %%
conn.commit()

# %%
conn.close()
